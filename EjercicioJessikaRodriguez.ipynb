# %% [markdown]
# <a href="https://colab.research.google.com/github/jessikawq/ModelosAnaliticosUnicafam202607/blob/main/EjercicioJessikaRodriguez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Operadores Matemáticos**

# %%
## 1 Declara dos variables a y b con los valores 10 y 3, respectivamente.
a = 10
b = 3

# %%
## Calcula la suma de a y b y asígnala a una variable suma.
suma = a + b
print(suma)
# Out:
# 13

# %%
#Calcula la resta de a y b y asígnala a una variable resta
resta = a-b
print(resta)
# Out:
# 7

# %%
#Calcula la multiplicación de a y b y asígnala a una variable multiplicacion.
multiplicacion = a * b
print(multiplicacion)
# Out:
# 30

# %%
#Calcula la división de a entre b y asígnala a una variable division.
division = a // b
print(division)
# Out:
# 3

# %%
#Calcula el módulo de a y b y asígnalo a una variable modulo.
modulo = a%b
print(modulo)
# Out:
# 1

# %%
# Calcula la potencia de a elevado a b y asígnala a una variable potencia.
potencia = a**b
print(potencia)
# Out:
# 1000

# %%
#Calcula la división entera de a entre b y asígnala a una variable division_entera
division = a/b
print(division)
# Out:
# 3.3333333333333335
